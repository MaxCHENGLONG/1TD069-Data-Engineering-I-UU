# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming data is in a CSV file with 'letter' and 'count' columns
data = pd.read_csv('output.csv')
plt.bar(data['letter'], data['count'])
plt.xlabel('Letter')
plt.ylabel('Count')
plt.title('Counts of Words Starting with Each Letter')
plt.show()
